# %% [markdown]
# https://data.sanantonio.gov/dataset/preliminary-plan-reviews

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
from datetime import date, timedelta
import datetime
import matplotlib.dates as mdates
# %matplotlib inline

# %%
! cat accelalanddevplanrevextract.csv
# Out:
# Project Name,Record ID,Application Type,Application Name,Received Date,Type of Review,Project Description,Other Description,Street #,Pre Direction,Street Name,Street Type,Post Direction,Unit/Suite,Level,Building,City,State,Zip Code,X-Coordinate,Y-Coordinate,Lat,Long,Parcel(s),Council District(s),Neighborhood Association(s),School District(s),Master Development Plan(s),San Antonio City Limits,Owner Name,Number of Stories,Land Sq Ft,Project Square Footage,Scheduled Meeting Date,Estimated Start Date,Estimated Construction Cost
# ,LAND-PPR-21-12300001,Preliminary Plan Review - Land Development,Ciudad de Las Palomas,1/8/2021 0:00,,85 acre single family subdivision,,6021,,TALLEY,RD,,,,,,TX,78253,2034079.3,13725833.6,29.490201,98.793853,686562,0,0,Medina Valley ISD,Ciudad De Las Palomas,,CIUDAD DE LAS PALOMAS LTD,,5320331.28,,1/25/2021 0:00,,
# ...

# %%
df_sa_plans = pd.read_csv('accelalanddevplanrevextract.csv')

# %%
df_sa_plans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Project Name                 144 non-null    object
#  1   Record ID                    185 non-null    object
#  2   Application Type             185 non-null    object
#  3   Application Name             87 non-null     object
#  4   Received Date                185 non-null    object
#  5   Type of Review               144 non-null    object
#  6   Project Description          185 non-null    object
#  7   Other Description            76 non-null     object
#  8   Street #                     130 non-null    float64
#  9   Pre Direction                38 non-null     object
#  10  Street Name                  131 non-null    object
#  11  Street Type                  82 non-null     object
#  12  Post Direction               8 non-null      object
# ...

# %%
df_sa_plans.iloc(0).name
# Out:
# 'iloc'

# %%
df_sa_plans.shape
# Out:
# (185, 36)

# %%
type(df_sa_plans)
# Out:
# pandas.core.frame.DataFrame

# %%
df_sa_plans.columns
# Out:
# Index(['Project Name', 'Record ID', 'Application Type', 'Application Name',
#        'Received Date', 'Type of Review', 'Project Description',
#        'Other Description', 'Street #', 'Pre Direction', 'Street Name',
#        'Street Type', 'Post Direction', 'Unit/Suite', 'Level', 'Building',
#        'City', 'State', 'Zip Code', 'X-Coordinate', 'Y-Coordinate', 'Lat',
#        'Long', 'Parcel(s)', 'Council District(s)',
#        'Neighborhood Association(s)', 'School District(s)',
#        'Master Development Plan(s)', 'San Antonio City Limits', 'Owner Name',
#        'Number of Stories', 'Land Sq Ft', 'Project Square Footage',
#        'Scheduled Meeting Date', 'Estimated Start Date',
#        'Estimated Construction Cost'],
#       dtype='object')

# %%
df_sa_plans.tail()
# Out:
#                  Project Name             Record ID  \
# 180   Fiesta Trails Apartment  REQ-BPPR-21-42800167
# 181             Saint Ephraim  REQ-BPPR-21-42800168
# 182       Prose MV - Phase II  REQ-BPPR-21-42800169
# 183           Promesa Phase 2  REQ-BPPR-21-42800170
# 184  TX2407-Dutch Bros Coffee  REQ-BPPR-21-42800171
#
#                        Application Type Application Name   Received Date  \
# 180  Preliminary Plan Review - Building              NaN  9/28/2021 0:00
# 181  Preliminary Plan Review - Building              NaN  9/29/2021 0:00
# 182  Preliminary Plan Review - Building              NaN  9/29/2021 0:00
# 183  Preliminary Plan Review - Building              NaN  10/1/2021 0:00
# 184  Preliminary Plan Review - Building              NaN  10/1/2021 0:00
#
#     Type of Review                                Project Description  \
# 180  New Structure          4 Story Wood Framed Apartment Development
# ...

# %%
df_sa_plans['School District(s)'].unique()
# Out:
# array(['Medina Valley ISD', 'San Antonio ISD', 'Southwest ISD',
#        'East Central ISD', 'Southside ISD',
#        'Harlandale ISD, South San Antonio ISD', 'Harlandale ISD',
#        'Northside ISD', 'North East ISD', 'Judson ISD',
#        'South San Antonio ISD', 'Edgewood ISD', 'Alamo Heights ISD',
#        'Judson ISD, San Antonio ISD', 'Judson ISD, North East ISD', nan,
#        'North East ISD, Northside ISD',
#        'East Central ISD, San Antonio ISD',
#        'Medina Valley ISD, Northside ISD',
#        'Alamo Heights ISD, North East ISD'], dtype=object)

# %%
df_sa_plans[df_sa_plans['School District(s)'] =='North East ISD']
