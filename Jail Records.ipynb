# %% [markdown]
# http://apps.bexar.org/jailactivity/KB50061D20211004.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
# %matplotlib inline

# %%
Oct_4_21_Jail_df = pd.read_csv('http://apps.bexar.org/jailactivity/KB50061D20211004.txt',header=4)

# %%
Oct_4_21_Jail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 599 entries, ('0B202102868   01 26 2021 0041 WANG', ' SHENGLI                    A M 00000000  LINCOLN               LOS ANGELES') to (' ATTORNEY OF RECORD: NO ATTORNEY FOUND FOR JN 2040460.', nan)
# Data columns (total 1 columns):
#  #   Column                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                               --------------  -----
#  0                             W N      J N    CRT  CASE NBR       C H A R G E             S T A T U S                 BOND AMT     DAYS  149 non-null    object
# dtypes: object(1)
# memory usage: 37.2+ KB

# %%
# !wget http://apps.bexar.org/jailactivity/KB50061D20211004.txt
# Out:
# --2021-10-04 16:48:31--  http://apps.bexar.org/jailactivity/KB50061D20211004.txt
# Resolving apps.bexar.org (apps.bexar.org)... 208.83.180.56
# Connecting to apps.bexar.org (apps.bexar.org)|208.83.180.56|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://apps.bexar.org/jailactivity/KB50061D20211004.txt [following]
# --2021-10-04 16:48:31--  https://apps.bexar.org/jailactivity/KB50061D20211004.txt
# Connecting to apps.bexar.org (apps.bexar.org)|208.83.180.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69237 (68K) [text/plain]
# Saving to: ‘KB50061D20211004.txt’
#
# KB50061D20211004.tx 100%[===================>]  67.61K  68.8KB/s    in 1.0s
#
# 2021-10-04 16:48:32 (68.8 KB/s) - ‘KB50061D20211004.txt’ saved [69237/69237]

# %%
! cat KB50061D20211004.txt
# Out:
# 1RUN DATE 10/04/2021                       BEXAR COUNTY CRIMINAL JUSTICE INFORMATION SYSTEM              PAGE     1    PGM = KB50061A
#  RUN TIME 00:07:59                                    COUNTY JAIL ACTIVITY LIST                                        JCL = KBJ7060D
#                                                    STATE & COUNTY:  ADDRESS NO SID                                     CTL = KB70061C
# 0 BKG NO    DATE   TIME              N A M E               R/S   DOB              ADDRESS            CITY/ST/ZIP        AWC   ARR AGY
#                           W N      J N    CRT  CASE NBR       C H A R G E             S T A T U S                 BOND AMT     DAYS
# 0B202102868   01 26 2021 0041 WANG, SHENGLI                    A M 00000000  LINCOLN               LOS ANGELES, CA. 00000
#           10/03/2021 1759          J2004077 NM   600566             F3 VIOL BOND/PROT ORDER CASE DISMISSED    JDG MEZA       25000.00
# ...
