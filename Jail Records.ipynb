# %% [markdown]
# http://apps.bexar.org/jailactivity/KB50061D20211004.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import ssl
# %matplotlib inline

# %%
ssl._create_default_https_context = ssl._create_unverified_context

# %%
Oct_21_21_Jail_df = pd.read_csv('http://apps.bexar.org/jailactivity/KB50061D20220308.txt',header=4)

# %%
Oct_21_21_Jail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 783 entries, ('0B202122642   07 12 2021 2030 CASTORENO', ' ROBERT JEREMY         W M 00000000 3238 HEATHER HILL      SAN ANTONIO') to (' ATTORNEY OF RECORD: NO JN FOR BOOKING 202200040.', nan)
# Data columns (total 1 columns):
#  #   Column                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                               --------------  -----
#  0                             W N      J N    CRT  CASE NBR       C H A R G E             S T A T U S                 BOND AMT     DAYS  195 non-null    object
# dtypes: object(1)
# memory usage: 41.0+ KB

# %%
# !wget http://apps.bexar.org/jailactivity/KB50061D20211124.txt
# Out:
# --2022-03-08 13:57:38--  http://apps.bexar.org/jailactivity/KB50061D20211124.txt
# Resolving apps.bexar.org (apps.bexar.org)... 208.83.180.56
# Connecting to apps.bexar.org (apps.bexar.org)|208.83.180.56|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://apps.bexar.org/jailactivity/KB50061D20211124.txt [following]
# --2022-03-08 13:57:38--  https://apps.bexar.org/jailactivity/KB50061D20211124.txt
# Connecting to apps.bexar.org (apps.bexar.org)|208.83.180.56|:443... connected.
# ERROR: cannot verify apps.bexar.org's certificate, issued by ‘CN=Go Daddy Secure Certificate Authority - G2,OU=http://certs.godaddy.com/repository/,O=GoDaddy.com\\, Inc.,L=Scottsdale,ST=Arizona,C=US’:
#   Unable to locally verify the issuer's authority.
# To connect to apps.bexar.org insecurely, use `--no-check-certificate'.

# %%
! cat KB50061D20211124.txt
# Out:
# 1RUN DATE 11/24/2021                       BEXAR COUNTY CRIMINAL JUSTICE INFORMATION SYSTEM              PAGE     1    PGM = KB50061A
#  RUN TIME 00:08:10                                    COUNTY JAIL ACTIVITY LIST                                        JCL = KBJ7060D
#                                                    STATE & COUNTY:  ADDRESS NO SID                                     CTL = KB70061C
# 0 BKG NO    DATE   TIME              N A M E               R/S   DOB              ADDRESS            CITY/ST/ZIP        AWC   ARR AGY
#                           W N      J N    CRT  CASE NBR       C H A R G E             S T A T U S                 BOND AMT     DAYS
# 0B202019420   06 08 2020 0913 GARCIA, GIOVANNI FRANCISCO       L M 00000000 4850 CASTLE ROSE       SAN ANTONIO, TX. 78218
#           11/23/2021 0902          J1971193 D437 2020CR8368         F3 INJURY TO ELDERLY BI TRANSFER TO       SASH         ** RWOB **
#  ATTORNEY OF RECORD: 16104600 - POLLOCK, JULIE B
# ...
